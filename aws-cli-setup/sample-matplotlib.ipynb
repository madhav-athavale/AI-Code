# %%
from math import cos
import numpy as np

# %%
print(cos(-0.73908513))
# Out:
# 0.7390851353809316

# %%
ar = np.arange(-1, 1,0.05)
yp = np.array([cos(x) for x in ar])

# %%
yp.shape
# Out:
# (40,)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(ar, yp)
plt.show()
