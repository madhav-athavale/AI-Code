# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
diamonds.describe(exclude=np.number)
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
from sklearn.model_selection import train_test_split

# %%
X,y = diamonds.drop('price', axis = 1),diamonds[['price']]

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
cats = X.select_dtypes(exclude=np.number).columns.tolist()

# %%
cats
# Out:
# ['cut', 'color', 'clarity']

# %%
for col in cats:
    X[col] = X[col].astype('category')

# %%
X.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)

# %%
#!pip install xgboost

# %%
import xgboost as xgb

# %%
dtrain_reg = xgb.DMatrix(X_train, y_train, enable_categorical=True)

# %%
dtest_reg = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %%
params= {"objective": "reg:squarederror", "tree_method": "hist"}

# %%
n=100
model = xgb.train(params= params, dtrain=dtrain_reg, num_boost_round =n,)

# %%
from sklearn.metrics import mean_squared_error

# %%
preds = model.predict(dtest_reg)

# %%
rmse = mean_squared_error(y_test, preds,squared=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 rmse = mean_squared_error(y_test, preds,squared=False)
#
# File /opt/anaconda3/envs/bedrock-env/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File /opt/anaconda3/envs/bedrock-env/lib/python3.13/inspect.py:3309, in Signature.bind(self, *args, **kwargs)
#    3304 def bind(self, /, *args, **kwargs):
#    3305     """Get a BoundArguments object, that maps the passed `args`
#    3306     and `kwargs` to the function's signature.  Raises `TypeError`
#    3307     if the passed arguments can not be bound.
#    3308     """
# -> 3309     return self._bind(args, kwargs)
#
# File /opt/anaconda3/envs/bedrock-env/lib/python3.13/inspect.py:3298, in Signature._bind(self, args, kwargs, partial)
#    3288         raise TypeError(
#    3289             'got some positional-only arguments passed as '
#    3290             'keyword arguments: {arg!r}'.format(
#    (...)   3295             ),
#    3296         )
#    3297     else:
# -> 3298         raise TypeError(
#    3299             'got an unexpected keyword argument {arg!r}'.format(
#    3300                 arg=next(iter(kwargs))))
#    3302 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'

# %%
print(f"RMSE of the bae model : {rmse:.3f}")

# %%
params= {"objective": "reg:squarederror", "tree_method": "hist"}

# %%
n=10000

# %%
evals =[(dtest_reg, "validation"), (dtrain_reg, "train")]

# %%
#Early stopping - does not work in this setup

# %%
model = xgb.train(params=params, dtrain=dtrain_reg, num_boost_round = n, evals = evals,verbose_eval = 250,early_stopping_rounds=50)

# %%
# XGBoost Cross-Validation

# %%
n = 1000

# %%
results = xgb.cv(params,dtrain_reg, num_boost_round=n, nfold=5, early_stopping_rounds = 20)

# %%
results.head()

# %%
best_rmse = results['test-rmse-mean'].min()

# %%
best_rmse

# %%
#XGBoost Classification

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X, y = diamonds.drop("cut", axis=1), diamonds[["cut"]]

# %%
y_encoded = OrdinalEncoder().fit_transform(y)

# %%
cats = X.select_dtypes(exclude=np.number).columns.tolist()

# %%
cats

# %%
for col in cats:
    X[col] = X[col].astype('category')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_encoded, random_state =2, stratify=y_encoded)

# %%
dtrain_clf =xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_clf = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %%
params={"objective" : "multi:softprob", "treemethod" : "hist", "num_class" : 5}

# %%
n = 1000

# %%
results = xgb.cv(params, dtrain_clf, num_boost_round=n, nfold=5, metrics=["mlogloss", "auc", "merror"])

# %%
results.keys()

# %%
results['test-auc-mean'].max()

# %%
#XGBoost using Sklearn. Categorical is not working in this version.

# %%
xgb_classifier = xgb.XGBClassifier(n_estimators=100, objetive='binary:logistic',tree_method="gpu_hist",eta=0.1,max_depth=3)

# %%
dtrain =xgb.DMatrix(X_train, y_train, enable_categorical=True)

# %%
xgb_classifier.fit(X_train, y_train)
