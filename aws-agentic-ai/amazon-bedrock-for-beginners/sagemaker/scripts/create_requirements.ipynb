# %%
# Run this cell

with open('/Users/madhavathavale/workspace/MacMiniM2/AI-Code/aws-agentic-ai/amazon-bedrock-for-beginners/sagemaker/scripts/requirements.txt', 'w') as f:
    f.write("xgboost\njoblib\nnumpy\nscikit-learn\n")

print("✓ requirements.txt created")

# Verify
with open('/Users/madhavathavale/workspace/MacMiniM2/AI-Code/aws-agentic-ai/amazon-bedrock-for-beginners/sagemaker/scripts/requirements.txt', 'r') as f:
    print(f.read())
# Out:
# ✓ requirements.txt created
# xgboost
# joblib
# numpy
# scikit-learn
