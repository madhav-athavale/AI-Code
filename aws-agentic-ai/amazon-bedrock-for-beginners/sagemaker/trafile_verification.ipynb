# %%
import tarfile

# Check what's inside model.tar.gz
with tarfile.open('model.tar.gz', 'r:gz') as tar:
    print("Files in model.tar.gz:")
    for member in tar.getmembers():
        print(f"  {member.name}")
# Out:
# Files in model.tar.gz:
#   model.joblib
